# %%
import pandas as pd
import matplotlib.pyplot as mp
import seaborn as sns
import numpy as np
df = pd.read_csv('sequences.csv')

# %%
df
# Out:
#      Release_Date            Species                   Host  \
# 0      2023-05-04   Pestivirus bovis                    NaN
# 1      2023-05-04   Pestivirus tauri             Bos taurus
# 2      2023-05-04  Rodent pestivirus    Apodemus peninsulae
# 3      2023-05-04  Rodent pestivirus  Niviventer niviventer
# 4      2023-05-04       Pestivirus S     Scotophilus kuhlii
# ...           ...                ...                    ...
# 1158   1993-08-02   Pestivirus bovis                    NaN
# 1159   1993-08-02    Pestivirus suis                    NaN
# 1160   1993-08-02   Pestivirus bovis                    NaN
# 1161   1993-06-11   Pestivirus bovis                    NaN
# 1162   1990-06-15    Pestivirus suis                    NaN
#
#      Tissue_Specimen_Source Collection_Date
# 0                       NaN             NaN
# 1                       NaN      2004-12-08
# 2                       NaN         2014-08
# 3                       NaN         2014-12
# ...

# %%
species = df['Species']
species_frequency = species.value_counts().to_frame()

# %%
species_frequency
# Out:
#                                                  count
# Species
# Pestivirus suis                                    424
# Pestivirus bovis                                   290
# Pestivirus tauri                                   155
# Pestivirus scrofae                                  95
# Pangolin pestivirus                                 60
# Pestivirus brazilense                               26
# Pestivirus ovis                                     23
# Rodent pestivirus                                    9
# Pestivirus australiaense                             9
# Pestivirus sp.                                       6
# Pestivirus M                                         5
# Pestivirus L                                         4
# Pestivirus giraffae                                  3
# Pipistrellus bat pestivirus                          3
# Pestivirus aydinense                                 3
# Pestivirus P                                         3
# ...

# %%
species_count = df.nunique(1)

# %%
species_count
# Out:
# 0       2
# 1       4
# 2       4
# 3       4
# 4       4
#        ..
# 1158    2
# 1159    2
# 1160    2
# 1161    2
# 1162    2
# Length: 1163, dtype: int64

# %%
sns.set(style="whitegrid")
sns.histplot(species_frequency, x='count', y='Species', discrete=True )
# Out:
# C:\Users\yter5\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\yter5\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='count', ylabel='Species'>

# %%
species_frequency['Species']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'species'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[74], line 1
# ----> 1 species_frequency['species']
#
# ...
